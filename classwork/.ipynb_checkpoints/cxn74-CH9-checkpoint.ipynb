# %% [markdown]
# 02/26/2026

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Part 1

# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

print("X:\n", X)
print("Y:\n", Y)
print("A:\n", A)

# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"\nSlope: {m}, Intercept: {c}")
# Out:
# X:
#  [1 2 3 4 5]
# Y:
#  [1.2 2.8 3.6 4.5 5.1]
# A:
#  [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]
#
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
y = 0.95*X + 0.59

plt.scatter(X,Y)
plt.plot(X, y)
plt.show()

# %%
# Part 2

x = np.random.uniform(0, 10, 10)
y = np.random.uniform(0, 10, 10)
x.sort()

d = np.vstack([x, np.ones(len(x))]).T

m, c = np.linalg.lstsq(d, y, rcond=None)[0]

y1 = m*x + c

plt.scatter(x, y)
plt.plot(x, y1)
plt.show()

# %%
# Part 3

x = np.arange(0, 1, 0.01)
a = np.random.uniform(-1, 1, len(x))

A = np.vstack([x, np.ones(len(x))]).T

y = (3/2)*x + 0.7 + a


m, c = np.linalg.lstsq(A, y, rcond=None)[0]

y1 = m*x + c

plt.scatter(x, y)
plt.plot(x, y1)
plt.show()

# %%
# Challenge A

# %%
x = np.random.uniform(0, 10, 10)
y = np.random.uniform(0, 10, 10)
x.sort()

d = np.vstack([x, np.ones(len(x))]).T

m, c = np.linalg.lstsq(d, y, rcond=None)[0]

y1 = m*x + c

plt.scatter(x, y)
plt.plot(x, y1)
plt.show()

# %%
# Mean Squared Error (MSE)
mse_leastsquares = np.mean((y - y1)**2)
print(f'Mean Squared Error: {mse_leastsquares:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y1)**2)
r_squared_leastsquares = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_leastsquares:.4f}')
# Out:
# Mean Squared Error: 3.6128
# R-squared: 0.1264

# %%
degree = 3 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Polynomial Coefficients:  [   2.22730348  -44.02398046  285.90089815 -603.26791066]

# %%
# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 2.5888
# R-squared: 0.3740

# %%
if ((mse_leastsquares<mse_cubic) & (r_squared_leastsquares>r_squared_cubic)):
    print("Lower MSE =", mse_leastsquares, "\nHigher R-Squared Value =", r_squared_leastsquares)
    print("The Linear Least Squares method is a better fit because the MSE is closer to 0 and the R-Squared value is closer to 1 compared to the Polynomial fit.")
else:
    print("Lower MSE =", mse_cubic, "\nHigher R-Squared Value =", r_squared_cubic)
    print("The Polynomial fit method (cubic) is a better fit because the MSE is closer to 0 and the R-Squared value is closer to 1 compared to the Linear fit.")
# Out:
# Lower MSE = 2.5887905598684826
# Higher R-Squared Value = 0.37401094548907043
# The Polynomial fit method (cubic) is a better fit because the MSE is closer to 0 and the R-Squared value is closer to 1 compared to the Linear fit.

# %%
# Challenge B

# %%
degree = 4 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 2.1612
# R-squared: 0.4774

# %%
degree = 5 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 1.6401
# R-squared: 0.6034

# %%
degree = 8 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 0.0416
# R-squared: 0.9899

# %%
degree = 9 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 0.0000
# R-squared: 1.0000

# %%
degree = 10 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3326: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Mean Squared Error: 0.0000
# R-squared: 1.0000

# %%
degree = 2 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 3.5885
# R-squared: 0.1323

# %%
degree = 1 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 3.6128
# R-squared: 0.1264

# %%
degree = 0.9 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)

# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse_cubic = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse_cubic:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared_cubic = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared_cubic:.4f}')
# Out:
# Mean Squared Error: 4.1355
# R-squared: 0.0000

# %%
# Challenge C

degree = 3
V = np.vander(x, N=degree+1, increasing=True)

print(V)

# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)

polynomial = np.poly1d(coefficients[::-1])

y_pred = polynomial(x)

# Plotting the results
plt.plot(x, y1, 'g', label='Least Squares line')
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# [[  1.           5.19517154  26.98980732 140.21667882]
#  [  1.           5.33888786  28.50372358 152.17818375]
#  [  1.           6.22703902  38.77601497 241.45975831]
#  [  1.           6.76936189  45.82426039 310.20100187]
#  [  1.           6.89673685  47.56497914 328.04314425]
#  [  1.           7.36299613  54.21371201 399.17535173]
#  [  1.           7.46211509  55.6831616  415.51416033]
#  [  1.           7.49074162  56.11120999 420.31457593]
#  [  1.           7.6635573   58.73011054 450.0815675 ]
#  [  1.           7.98966771  63.83479006 510.01876064]]

# %% [markdown]
# citation: I search up in Google Gemini why my polynomial fit using the Vandermonde Matrix was not fitting my graph and found that np.poly1d reads coefficents in decreasing order, so I had to reverse the array for my code to work.
